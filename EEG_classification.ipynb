# %% [markdown]
# # Installation de nouvelles bibliothèques nécessaires

# %%
# !pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (4.64.1)

# %% [markdown]
# # Importation et labélisation des données

# %%
import os
from tqdm import tqdm
import glob
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

DATA_DIR_A = '/content/drive/MyDrive/A/'
DATA_DIR_B = '/content/drive/MyDrive/B/'
DATA_DIR_C = '/content/drive/MyDrive/C/'
DATA_DIR_D = '/content/drive/MyDrive/D/'
DATA_DIR_E = '/content/drive/MyDrive/E/'
  
LABEL_C1 = 0
#LABEL_C2 = 1
#LABEL_C3 = 2
#LABEL_C4 = 3
LABEL_C5 = 4
def load_data():
    data = []
    nbFiles = 0
    for fname in tqdm(os.listdir(DATA_DIR_A)):
        img = np.loadtxt(DATA_DIR_A + fname)
        data.append(img)
        nbFiles+=1
    
    #for fname in tqdm(os.listdir(DATA_DIR_B)):
    #    img = np.loadtxt(DATA_DIR_B + fname)
   #     data.append([img, np.array(LABEL_C2)])
  #      nbFiles+=1    
    
    #for fname in tqdm(os.listdir(DATA_DIR_C)):
   #     img = np.loadtxt(DATA_DIR_C + fname)
  #    data.append([np.array(img), np.array(LABEL_C3)])
   #     nbFiles+=1

    #for fname in tqdm(os.listdir(DATA_DIR_D)):
    #    img = np.loadtxt(DATA_DIR_D + fname)
    #    data.append([np.array(img), np.array(LABEL_C4)])
    #    nbFiles+=1

    for fname in tqdm(os.listdir(DATA_DIR_E)):
        img = np.loadtxt(DATA_DIR_E + fname)
        data.append(img)
        nbFiles+=1
        
    return data


data = load_data()
print("\n",len(data), "Files of data loaded")
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 64.14it/s]
# 100%|██████████| 100/100 [00:01<00:00, 63.71it/s]
#  200 Files of data loaded

# %%
data
# Out:
# [array([ 12.,  22.,  35., ..., -11.,   8.,  77.]),
#  array([ -56.,  -50.,  -64., ..., -173., -162.,  -82.]),
#  array([-37., -22., -17., ...,   3.,   4.,  82.]),
#  array([-31., -43., -39., ...,  -6.,  10.,  33.]),
#  array([ 14.,  26.,  32., ..., -32.,  -6., -17.]),
#  array([-87., -89., -73., ...,  18.,   7.,   7.]),
#  array([ -2.,  20.,  42., ..., -18.,  -6., -37.]),
#  array([-31., -16.,  10., ...,   1.,   1.,   0.]),
#  array([  8.,  17.,  29., ..., -40., -36.,   7.]),
#  array([-41., -38., -31., ...,   1., -13.,  -1.]),
#  array([ 14.,  25.,  31., ..., -26., -28.,  21.]),
#  array([-64., -72., -52., ..., -36., -58.,  20.]),
#  array([ 10.,  -6., -14., ...,  15.,   6., -46.]),
#  array([31., 25., 17., ..., 23., 28., 65.]),
#  array([ 30.,  19.,  -3., ..., -11., -13.,  -6.]),
#  array([ 34.,  34.,  31., ...,  -7., -20.,  91.]),
#  array([-62., -55., -44., ..., -20., -22.,  35.]),
#  array([-18.,  -9.,   9., ..., 109.,  67.,  50.]),
#  array([  0.,   2.,  -1., ...,  23.,  21., -16.]),
#  array([-20.,  -3.,   2., ..., -28., -10.,   3.]),
#  array([-58., -59., -60., ..., -43., -59.,  23.]),
#  array([  6., -14., -33., ...,  22.,  26., -88.]),
#  array([-40., -13.,  43., ..., -21., -26.,  28.]),
#  array([ -1., -40., -56., ...,  20.,   4.,  15.]),
#  array([  28.,   30.,    8., ..., -105.,  -95.,  -26.]),
#  array([67., 86., 89., ..., -5.,  9., -1.]),
#  array([19., 14., 23., ..., 62., 54., 40.]),
#  array([ -4.,   4.,  10., ..., -40., -45., -58.]),
#  array([-42., -49., -37., ..., -16., -19., -40.]),
#  array([ 96.,  43.,  71., ...,  51.,  90., -28.]),
#  array([-21., -29., -34., ...,  18.,   6.,  25.]),
#  array([-41., -37., -29., ..., -20., -23., -59.]),
#  array([-26., -29., -39., ...,  73.,  16.,  55.]),
#  array([-10.,  -9., -33., ..., -29., -18., -51.]),
#  array([-19., -39., -41., ...,  60.,  46.,  46.]),
#  array([ 40.,  60.,  74., ..., -12.,   8.,  61.]),
#  array([-49., -48., -46., ...,  18.,  -1.,  -9.]),
#  array([ -73.,  -66.,  -59., ..., -113., -109.,  -93.]),
#  array([ 18.,  34.,  45., ..., -57., -53.,  83.]),
#  array([ 63.,  43.,  47., ...,  -1.,  14., -14.]),
#  array([ -45., -105., -106., ...,   22.,    5.,   96.]),
#  array([-81., -79., -76., ..., -27., -39., -70.]),
#  array([-19.,   9.,  35., ..., -53., -48.,  -1.]),
#  array([-46., -44., -47., ...,  43.,  56.,  14.]),
#  array([-21.,  -6.,   1., ..., -40., -15.,  23.]),
#  array([-13., -27., -39., ..., -30., -34., -85.]),
#  array([  7.,  11.,  20., ..., -56., -48., -23.]),
#  array([ -7.,   4.,  21., ..., -94., -95.,  59.]),
#  array([ 26.,  10.,   7., ...,  96.,  82., -18.]),
#  array([81., 68., 35., ..., 15., 10., 17.]),
#  array([-12.,   6.,  13., ..., -46., -30., -46.]),
#  array([ 43.,  48.,  44., ..., -47., -21.,  27.]),
#  array([-20., -12.,  -6., ...,   9.,   2., -14.]),
#  array([ 69.,  68.,  58., ..., -83., -75.,  58.]),
#  array([ -91., -116.,  -70., ...,    7.,  -22., -121.]),
#  array([46., 42., 29., ..., 36., 60., 44.]),
#  array([ 37.,  50.,  58., ..., -54., -56., -41.]),
#  array([-44., -35., -18., ...,  44.,  55.,  66.]),
#  array([-20., -23., -24., ...,  14.,  13.,   2.]),
#  array([-64., -62., -59., ..., -30., -41., -93.]),
#  array([-53., -46., -47., ..., -74., -80., -54.]),
#  array([-55., -32.,   1., ..., -73., -65., -39.]),
#  array([-40., -33., -16., ...,  23.,   5.,  10.]),
#  array([-20., -43., -47., ...,  18.,   8., -63.]),
#  array([ -9.,  15.,  35., ..., -30., -12.,  -3.]),
#  array([-15., -23., -25., ...,  34.,  12., -51.]),
#  array([-49., -59., -56., ...,   8.,  -1., -44.]),
#  array([20., 21., 19., ..., 39., 18., 30.]),
#  array([-25.,   7.,  37., ..., -83., -69., -75.]),
#  array([-13.,  -4.,   2., ...,  74.,  61.,  -5.]),
#  array([  13.,   21.,   39., ..., -107., -109.,  -25.]),
#  array([113., 129., 108., ..., -41., -22.,  -5.]),
#  array([-17., -36., -52., ...,  -6., -31., -19.]),
#  array([-48., -52., -63., ...,  -5.,  -9.,   0.]),
#  array([ 24.,  10.,  -9., ..., -33., -28., -19.]),
#  array([ 39.,  41.,  43., ..., -29., -16.,   1.]),
#  array([ 57.,  82.,  93., ..., -72., -55., -20.]),
#  array([ -8., -19., -32., ...,  27.,  41., -21.]),
#  array([ 69.,  69.,  65., ..., -17.,  -1.,  -3.]),
#  array([-34., -21., -17., ..., -73., -61., -69.]),
#  array([36., 27., 24., ..., 66., 59.,  6.]),
#  array([  20.,   27.,   -5., ..., -111.,  -71.,   -9.]),
#  array([ -56.,  -55.,  -53., ..., -102.,  -73., -115.]),
#  array([-20., -14., -12., ..., -66., -53.,   5.]),
#  array([-44., -63., -85., ...,  20., -25.,  15.]),
#  array([-21., -14., -12., ..., -82., -66., -10.]),
#  array([ -2.,  -8., -27., ...,  21.,  17., -16.]),
#  array([  -1.,  -11.,  -11., ...,  -31.,  -31., -111.]),
#  array([ 16.,  24.,  33., ..., -75., -45., -68.]),
#  array([-30., -34., -33., ...,   1., -20., -27.]),
#  array([ 13.,  30.,  42., ..., -36., -22., -39.]),
#  array([ 40.,  48.,  35., ..., -34., -27., -42.]),
#  array([-19.,  -1.,  33., ..., -70., -25.,  -2.]),
#  array([-45., -62., -76., ..., -24., -56.,  49.]),
#  array([ 6., -6., -8., ..., 98., 78., -5.]),
#  array([-133., -144., -113., ...,  -83.,  -87., -104.]),
#  array([ -3.,  -3., -12., ...,  30.,  19., -64.]),
#  array([-51., -42., -39., ...,  -2.,   0., -49.]),
#  array([ 56.,  55.,  38., ..., -32.,  -4.,  69.]),
#  array([ -36.,  -71., -120., ...,    3.,  -13.,   30.]),
#  array([100., 124., 153., ...,  57.,  95., 462.]),
#  array([340., 353., 400., ..., 512., 130., 196.]),
#  array([-310.,   93.,  494., ..., -721., -491.,  910.]),
#  array([  84.,   75.,   21., ..., -209., -165., -212.]),
#  array([343., 311., 284., ..., 480., 397., 217.]),
#  array([ -88., -115., -140., ...,  146.,  140.,  191.]),
#  array([ 176.,  186.,  189., ...,  101.,   99., -554.]),
#  array([ 661.,  721.,  702., ...,   12.,   29., -211.]),
#  array([-377., -379., -396., ...,  -89., -132., -279.]),
#  array([ 374., -205., -871., ...,  633.,  503.,  803.]),
#  array([ 142.,  262.,  382., ..., -201., -140., -362.]),
#  array([ 457.,  420.,  344., ..., -226., -206., 1002.]),
#  array([746., 692., 562., ..., 565., 677.,  11.]),
#  array([ -63., -107., -208., ...,   44.,  -37.,   28.]),
#  array([-174., -392., -470., ...,  187.,  157., -260.]),
#  array([-115., -117., -127., ...,  -14.,  -17.,  -25.]),
#  array([ 800.,  839.,  857., ..., -670., -296., -677.]),
#  array([ -46.,  -43.,  -37., ..., -116., -128.,  107.]),
#  array([-501., -540., -523., ...,  418.,  345., -230.]),
#  array([   1.,  -47., -100., ...,   77.,   78., -320.]),
#  array([ 213.,  210.,  210., ...,   -2.,   20., -231.]),
#  array([ -54.,  -26.,   20., ..., -470., -365.,   28.]),
#  array([  27.,   55.,   75., ..., -476., -307.,  -21.]),
#  array([ -40., -187., -254., ...,  478.,  288.,   87.]),
#  array([-445., -645., -652., ...,  264.,  219., -346.]),
#  array([ 231.,  214.,  187., ...,  243.,  198., -231.]),
#  array([ -782., -1221., -1406., ...,    96.,  -299.,  -279.]),
#  array([-345., -166.,   91., ..., -472., -302.,  940.]),
#  array([  59.,   37.,   25., ...,  366.,  199., -224.]),
#  array([475., 501., 477., ..., 103., 136.,  55.]),
#  array([-156.,  -74.,   51., ..., -269.,   30., -190.]),
#  array([  -9.,   68.,  195., ..., -135., -129.,  -82.]),
#  array([216., 182., 146., ..., 355., 218., 391.]),
#  array([ -18.,  -55., -126., ..., -200., -127., -226.]),
#  array([-458., -669., -914., ...,  356.,   87.,  215.]),
#  array([258., 309., 308., ...,  66.,  73., 206.]),
#  array([ 530.,  523.,  424., ...,  327.,  285., -925.]),
#  array([264., 372., 410., ...,  -5.,  27., 464.]),
#  array([-71., -83., -95., ..., 100.,  94.,  59.]),
#  array([284., 358., 122., ...,  48.,  95., 211.]),
#  array([  15., -218., -643., ...,  271.,  259.,  159.]),
#  array([-265., -440., -627., ...,  -55.,  -74.,   -4.]),
#  array([-285., -308., -312., ...,  -67.,  -55., -107.]),
#  array([-166., -204., -209., ...,  368.,  313.,   51.]),
#  array([-149., -145., -135., ...,  -27.,  -27.,  228.]),
#  array([466., 481., 440., ..., -72., -67., 523.]),
#  array([  -10.,  -658., -1254., ...,   678.,   540., -1852.]),
#  array([ 401.,  577.,  667., ...,  -94.,  -77., -202.]),
#  array([-224., -334., -411., ...,  380.,  294.,   32.]),
#  array([-183., -188., -199., ..., -174., -170., -141.]),
#  array([ 98.,  88.,  76., ..., 244., 184.,  70.]),
#  array([-235.,  -94.,  116., ..., -365., -274.,  149.]),
#  array([ 119.,  125.,  129., ..., -213., -180.,  221.]),
#  array([111., 112., 125., ..., 211., 181., -51.]),
#  array([ -22.,  -63.,  -90., ...,   74.,   60., -106.]),
#  array([  39.,  152.,  257., ...,  -94.,  -97., -108.]),
#  array([  29.,  -68., -143., ...,  135.,   81.,  194.]),
#  array([-187., -132.,  -53., ..., -130., -150.,  375.]),
#  array([-635., -573., -525., ..., -370., -415., -593.]),
#  array([ 509.,  495.,  464., ..., -175.,  166., -448.]),
#  array([-192., -207., -202., ...,   29., -149., -109.]),
#  array([249., 218., 176., ..., 367., 299.,  26.]),
#  array([ 224.,  199.,  149., ...,  -56.,  -56., -101.]),
#  array([  22.,  -67., -184., ...,  149.,   69.,  158.]),
#  array([-300., -334., -341., ..., -142., -142., -184.]),
#  array([-358., -378., -365., ...,   50.,   34.,   62.]),
#  array([  555.,   611.,   658., ...,   347.,   369., -1468.]),
#  array([ -114.,  -248.,  -388., ...,   484.,   397., -1566.]),
#  array([  68., -106., -149., ...,  343.,  247., -468.]),
#  array([ -62.,  -87., -129., ...,  -29.,  -23.,  313.]),
#  array([ 61.,  42.,  23., ..., 318., 261., 177.]),
#  array([ 271.,  291.,  267., ..., -263., -229., -289.]),
#  array([-133., -181., -166., ...,   95.,   19.,  385.]),
#  array([ -21.,  -17.,  -16., ..., -230., -207.,  -32.]),
#  array([  45.,   51.,   62., ...,   -5.,    9., -282.]),
#  array([ -985.,  -594.,  -120., ..., -1073.,  -734., -1111.]),
#  array([122., 117., 116., ..., -23.,  55.,  51.]),
#  array([-177., -237., -266., ...,  -70.,  -81.,   44.]),
#  array([-459., -778., -981., ...,   -8.,  -11.,  949.]),
#  array([249., 235., 220., ..., 231., 257., 327.]),
#  array([235., 168., 113., ..., 375., 354., 607.]),
#  array([-127., -164., -184., ...,  110.,   89.,  716.]),
#  array([ -34.,  -11.,    8., ..., -203., -156.,   24.]),
#  array([-24., -29., -17., ...,  -7.,  -7.,  43.]),
#  array([ 184., -160., -569., ...,  668.,  530.,  314.]),
#  array([ 43.,  59.,  69., ...,  27.,  69., 105.]),
#  array([286., 251., 214., ..., 334., 188., 315.]),
#  array([80., 86., 91., ..., 54., 78., 89.]),
#  array([ 151.,   25.,  -82., ...,   84.,  119., -226.]),
#  array([ 134.,  390.,  446., ..., -153.,  -62.,   72.]),
#  array([-129., -309., -432., ...,   12., -254.,  -57.]),
#  array([ -26.,    1.,   29., ..., -207., -210., -107.]),
#  array([ 308.,  367.,  413., ..., -557., -305., -859.]),
#  array([-155., -283., -456., ...,  -27.,  -85., -449.]),
#  array([-113., -185., -269., ...,  148.,  111., -235.]),
#  array([ -40.,  -58.,  -75., ...,  -13.,  -16., -151.]),
#  array([ 187.,   44., -147., ...,  703.,  446., -537.]),
#  array([-438., -561., -622., ..., -118., -163.,  -56.]),
#  array([-476., -518., -521., ...,  246.,  556.,  276.]),
#  array([  23.,  144.,  228., ..., -155.,    6., -221.])]

# %% [markdown]
# # Visualisation d'un échantillon de données

# %%
"""import random
mpl.rcParams['figure.figsize'] = (20,10)

fig = plt.figure()

samples_c1 = np.empty((0, 4097), int)
while len(samples_c1) < 4:
    curID = random.randint(0, len(data))
    if data[curID][1] == LABEL_C1:
        samples_c1 = np.vstack((samples_c1, data[curID][0]))
        
samples_c2 = np.empty((0, 4097), int)
while len(samples_c2) < 4:
    curID = random.randint(0, len(data))
    if data[curID][1] == LABEL_C5:
        samples_c2 = np.vstack((samples_c2, data[curID][0]))
        
for i in range(0, 4):
    plt.subplot(421 + i * 2)
    plt.plot(samples_c1[i])
    plt.subplot(421 + i * 2 + 1)
    plt.plot(samples_c2[i])

ax = plt.subplot(421)
ax.set_title("CLASS 1")
ax = plt.subplot(422)
ax.set_title("CLASS 5")

fig.suptitle("A vs E", fontsize=20)
plt.show()"""
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-3d5b7a4df8ed> in <module>
#       7 while len(samples_c1) < 4:
#       8     curID = random.randint(0, len(data))
# ----> 9     if data[curID][1] == LABEL_C1:
#      10         samples_c1 = np.vstack((samples_c1, data[curID][0]))
#      11
#
# IndexError: list index out of range

# %%
type(np.array(data, dtype=object))
# Out:
# numpy.ndarray

# %% [markdown]
# #Pré-traitement des données

# %%
# !pip install PyWavelets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: PyWavelets in /usr/local/lib/python3.8/dist-packages (1.3.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from PyWavelets) (1.21.6)

# %%
import pywt

# %%
def wavelet_haar_pso (data):
  data=pywt.wavedec(data, 'haar',mode='sym', level=4)
  return data

# %%
def wavelet_daubechie_pso (data):
  data=pywt.wavedec(data, 'db4',mode='sym', level=4)
  return data

# %%
def wavelet_symlet_pso (data):
  data=pywt.wavedec(data, 'sym8',mode='sym', level=4)
  return data

# %%
pywt.wavelist()

# %%
wavelet_symlet_pso (data)
# Out:
# [array([[  196.3510768 ,   179.23483508,   181.93072161, ...,
#             -6.42928256,    -8.15375885,   -36.35144646],
#         [ -373.28763737,  -369.81603098,  -370.16407518, ...,
#           -613.09361462,  -615.13258557,  -525.30234362],
#         [  -96.07798976,   -90.493091  ,   -94.28196416, ...,
#             44.35924086,    52.56063434,   -31.4147561 ],
#         ...,
#         [-1957.72958719, -1794.04414068, -1888.3570808 , ...,
#             82.05807964,   210.74727818,   482.68430389],
#         [-1035.49251003, -1030.40090674,  -982.64759166, ...,
#            844.7433565 ,   727.25492568,   295.78972307],
#         [  909.82418178,   680.85277433,   752.49235579, ...,
#           -731.73186385,  -725.72890767,  -668.24823727]]),
#  array([[ -96.51950088,  -10.90807766,   32.58586412, ...,   96.46508347,
#            39.34317074,   43.95975115],
#         [  56.78478591,   41.0808577 ,  -54.06887997, ...,  -44.06857376,
#            54.68190893,  -17.40354573],
#         [  20.69406731,  -30.15615417,   11.33483054, ...,  129.33000453,
#            12.07320422,   69.24794335],
#         ...,
#         [ 514.53439259, -471.8883587 ,  215.4246786 , ..., -958.32280205,
#           -99.75237349, -456.45514469],
#         [ -22.93749126, -375.23421292,  381.17785694, ..., 1128.46381621,
#           141.89426037,  532.80915961],
#         [-938.82430192,  227.71385888,   27.41001398, ...,   19.10835875,
#            87.32108014,    4.69938814]]),
#  array([[-4.61557782e+01,  4.84479779e+01, -8.68454525e-02, ...,
#           3.75623164e+01,  2.27030323e+01, -1.29699640e+00],
#         [ 3.37337914e+01, -7.20097895e+01, -5.41118479e+00, ...,
#           7.96572735e+01,  1.23121865e+01,  2.45104283e+01],
#         [-1.55050879e+01, -6.71138257e+00,  4.11662993e+00, ...,
#           5.94563956e+00,  2.39531475e+01, -1.52122620e+01],
#         ...,
#         [ 3.16513918e+01, -4.50554718e+01,  1.54036470e+02, ...,
#           2.33927995e+02, -2.87110828e+01,  1.11362178e+02],
#         [-1.07135278e+03,  5.77998473e+02,  1.10771619e+02, ...,
#          -2.74050617e+02,  2.78386449e+01, -1.10966959e+02],
#         [-5.10073750e+01,  1.82370573e+02, -7.41868302e+01, ...,
#           1.24745496e+02,  5.64042398e+01,  1.37770591e+00]]),
#  array([[ -13.94665816,    5.62503629,    1.22543215, ...,   -6.96561049,
#            -1.23183181,   67.38461629],
#         [   6.89347379,  -34.28903825,   -5.53822309, ...,   28.17485089,
#            -1.04939267,   67.96059583],
#         [  14.91497529,  -25.50136533,   -0.97374588, ...,   -5.60611268,
#            19.5815139 ,   65.55798109],
#         ...,
#         [ -94.46688249,  127.74883045,   40.81134741, ...,   42.47582835,
#           -13.52516466,  126.90393443],
#         [-252.45960257,  247.22421381,   33.46524305, ..., -107.30973837,
#             9.16275785,  -96.69058165],
#         [  -0.32720992,  -68.89808777,  -17.23658321, ...,   57.63805371,
#          -190.97293098, -106.44078534]]),
#  array([[ 2.63695574e+00, -6.27611038e+00, -2.27584113e+00, ...,
#          -5.10917280e+00,  1.51603171e+00, -1.15704411e-01],
#         [ 3.70430989e+00,  9.79914641e+00, -2.95341312e+00, ...,
#          -5.55346161e+00, -5.94914812e-01, -2.21693923e-01],
#         [-8.01702643e-03,  5.27171711e+00, -5.20835242e+00, ...,
#          -4.45039062e+00,  6.07294261e+00,  2.21109488e+00],
#         ...,
#         [-2.64819337e+00,  8.26886606e-01,  1.85572798e+01, ...,
#          -1.36182106e+01,  2.38060572e+01, -7.11493739e+00],
#         [-3.59086761e+01, -5.09386274e+00,  2.26946579e+01, ...,
#           1.79211173e+02, -6.69231167e+01,  2.60848280e+01],
#         [-1.80388601e+00,  2.84740151e+00, -1.47672734e+01, ...,
#           3.57035664e+01, -1.95119788e+01, -1.08754808e+01]])]

# %%
shuffle(data)
# Out:
# [[array([-458., -669., -914., ...,  356.,   87.,  215.]), array(4)],
#  [array([ 134.,  390.,  446., ..., -153.,  -62.,   72.]), array(4)],
#  [array([-19.,   9.,  35., ..., -53., -48.,  -1.]), array(0)],
#  [array([ -9.,  15.,  35., ..., -30., -12.,  -3.]), array(0)],
#  [array([ 69.,  69.,  65., ..., -17.,  -1.,  -3.]), array(0)],
#  [array([-345., -166.,   91., ..., -472., -302.,  940.]), array(4)],
#  [array([-187., -132.,  -53., ..., -130., -150.,  375.]), array(4)],
#  [array([343., 311., 284., ..., 480., 397., 217.]), array(4)],
#  [array([-51., -42., -39., ...,  -2.,   0., -49.]), array(0)],
#  [array([-17., -36., -52., ...,  -6., -31., -19.]), array(0)],
#  [array([-41., -37., -29., ..., -20., -23., -59.]), array(0)],
#  [array([ -88., -115., -140., ...,  146.,  140.,  191.]), array(4)],
#  [array([-31., -43., -39., ...,  -6.,  10.,  33.]), array(0)],
#  [array([-459., -778., -981., ...,   -8.,  -11.,  949.]), array(4)],
#  [array([ -114.,  -248.,  -388., ...,   484.,   397., -1566.]), array(4)],
#  [array([ 40.,  60.,  74., ..., -12.,   8.,  61.]), array(0)],
#  [array([-183., -188., -199., ..., -174., -170., -141.]), array(4)],
#  [array([-156.,  -74.,   51., ..., -269.,   30., -190.]), array(4)],
#  [array([-438., -561., -622., ..., -118., -163.,  -56.]), array(4)],
#  [array([ -40., -187., -254., ...,  478.,  288.,   87.]), array(4)],
#  [array([-49., -48., -46., ...,  18.,  -1.,  -9.]), array(0)],
#  [array([-13.,  -4.,   2., ...,  74.,  61.,  -5.]), array(0)],
#  [array([67., 86., 89., ..., -5.,  9., -1.]), array(0)],
#  [array([-26., -29., -39., ...,  73.,  16.,  55.]), array(0)],
#  [array([216., 182., 146., ..., 355., 218., 391.]), array(4)],
#  [array([  22.,  -67., -184., ...,  149.,   69.,  158.]), array(4)],
#  [array([-235.,  -94.,  116., ..., -365., -274.,  149.]), array(4)],
#  [array([-37., -22., -17., ...,   3.,   4.,  82.]), array(0)],
#  [array([ 6., -6., -8., ..., 98., 78., -5.]), array(0)],
#  [array([-31., -16.,  10., ...,   1.,   1.,   0.]), array(0)],
#  [array([ -62.,  -87., -129., ...,  -29.,  -23.,  313.]), array(4)],
#  [array([ 16.,  24.,  33., ..., -75., -45., -68.]), array(0)],
#  [array([-115., -117., -127., ...,  -14.,  -17.,  -25.]), array(4)],
#  [array([ 213.,  210.,  210., ...,   -2.,   20., -231.]), array(4)],
#  [array([ -34.,  -11.,    8., ..., -203., -156.,   24.]), array(4)],
#  [array([-21., -14., -12., ..., -82., -66., -10.]), array(0)],
#  [array([-34., -21., -17., ..., -73., -61., -69.]), array(0)],
#  [array([-30., -34., -33., ...,   1., -20., -27.]), array(0)],
#  [array([-133., -144., -113., ...,  -83.,  -87., -104.]), array(0)],
#  [array([36., 27., 24., ..., 66., 59.,  6.]), array(0)],
#  [array([ 37.,  50.,  58., ..., -54., -56., -41.]), array(0)],
#  [array([ -1., -40., -56., ...,  20.,   4.,  15.]), array(0)],
#  [array([-40., -13.,  43., ..., -21., -26.,  28.]), array(0)],
#  [array([-177., -237., -266., ...,  -70.,  -81.,   44.]), array(4)],
#  [array([-44., -35., -18., ...,  44.,  55.,  66.]), array(0)],
#  [array([ -91., -116.,  -70., ...,    7.,  -22., -121.]), array(0)],
#  [array([249., 235., 220., ..., 231., 257., 327.]), array(4)],
#  [array([-20., -12.,  -6., ...,   9.,   2., -14.]), array(0)],
#  [array([-20., -23., -24., ...,  14.,  13.,   2.]), array(0)],
#  [array([-501., -540., -523., ...,  418.,  345., -230.]), array(4)],
#  [array([ 14.,  26.,  32., ..., -32.,  -6., -17.]), array(0)],
#  [array([-19.,  -1.,  33., ..., -70., -25.,  -2.]), array(0)],
#  [array([ 24.,  10.,  -9., ..., -33., -28., -19.]), array(0)],
#  [array([ -46.,  -43.,  -37., ..., -116., -128.,  107.]), array(4)],
#  [array([284., 358., 122., ...,  48.,  95., 211.]), array(4)],
#  [array([ -985.,  -594.,  -120., ..., -1073.,  -734., -1111.]), array(4)],
#  [array([235., 168., 113., ..., 375., 354., 607.]), array(4)],
#  [array([  0.,   2.,  -1., ...,  23.,  21., -16.]), array(0)],
#  [array([ -54.,  -26.,   20., ..., -470., -365.,   28.]), array(4)],
#  [array([100., 124., 153., ...,  57.,  95., 462.]), array(4)],
#  [array([-358., -378., -365., ...,   50.,   34.,   62.]), array(4)],
#  [array([340., 353., 400., ..., 512., 130., 196.]), array(4)],
#  [array([-113., -185., -269., ...,  148.,  111., -235.]), array(4)],
#  [array([ 151.,   25.,  -82., ...,   84.,  119., -226.]), array(4)],
#  [array([ 26.,  10.,   7., ...,  96.,  82., -18.]), array(0)],
#  [array([ 308.,  367.,  413., ..., -557., -305., -859.]), array(4)],
#  [array([-45., -62., -76., ..., -24., -56.,  49.]), array(0)],
#  [array([-40., -33., -16., ...,  23.,   5.,  10.]), array(0)],
#  [array([113., 129., 108., ..., -41., -22.,  -5.]), array(0)],
#  [array([ 119.,  125.,  129., ..., -213., -180.,  221.]), array(4)],
#  [array([   1.,  -47., -100., ...,   77.,   78., -320.]), array(4)],
#  [array([  -9.,   68.,  195., ..., -135., -129.,  -82.]), array(4)],
#  [array([ 56.,  55.,  38., ..., -32.,  -4.,  69.]), array(0)],
#  [array([ 509.,  495.,  464., ..., -175.,  166., -448.]), array(4)],
#  [array([  -10.,  -658., -1254., ...,   678.,   540., -1852.]), array(4)],
#  [array([-21., -29., -34., ...,  18.,   6.,  25.]), array(0)],
#  [array([ 57.,  82.,  93., ..., -72., -55., -20.]), array(0)],
#  [array([249., 218., 176., ..., 367., 299.,  26.]), array(4)],
#  [array([ 800.,  839.,  857., ..., -670., -296., -677.]), array(4)],
#  [array([ 10.,  -6., -14., ...,  15.,   6., -46.]), array(0)],
#  [array([ -63., -107., -208., ...,   44.,  -37.,   28.]), array(4)],
#  [array([-48., -52., -63., ...,  -5.,  -9.,   0.]), array(0)],
#  [array([-15., -23., -25., ...,  34.,  12., -51.]), array(0)],
#  [array([-310.,   93.,  494., ..., -721., -491.,  910.]), array(4)],
#  [array([ 142.,  262.,  382., ..., -201., -140., -362.]), array(4)],
#  [array([  7.,  11.,  20., ..., -56., -48., -23.]), array(0)],
#  [array([ 187.,   44., -147., ...,  703.,  446., -537.]), array(4)],
#  [array([ -40.,  -58.,  -75., ...,  -13.,  -16., -151.]), array(4)],
#  [array([-300., -334., -341., ..., -142., -142., -184.]), array(4)],
#  [array([  29.,  -68., -143., ...,  135.,   81.,  194.]), array(4)],
#  [array([ 63.,  43.,  47., ...,  -1.,  14., -14.]), array(0)],
#  [array([-476., -518., -521., ...,  246.,  556.,  276.]), array(4)],
#  [array([ 43.,  59.,  69., ...,  27.,  69., 105.]), array(4)],
#  [array([ 271.,  291.,  267., ..., -263., -229., -289.]), array(4)],
#  [array([-87., -89., -73., ...,  18.,   7.,   7.]), array(0)],
#  [array([-192., -207., -202., ...,   29., -149., -109.]), array(4)],
#  [array([ 661.,  721.,  702., ...,   12.,   29., -211.]), array(4)],
#  [array([-10.,  -9., -33., ..., -29., -18., -51.]), array(0)],
#  [array([-44., -63., -85., ...,  20., -25.,  15.]), array(0)],
#  [array([20., 21., 19., ..., 39., 18., 30.]), array(0)],
#  [array([-129., -309., -432., ...,   12., -254.,  -57.]), array(4)],
#  [array([  15., -218., -643., ...,  271.,  259.,  159.]), array(4)],
#  [array([-18.,  -9.,   9., ..., 109.,  67.,  50.]), array(0)],
#  [array([-71., -83., -95., ..., 100.,  94.,  59.]), array(4)],
#  [array([ -56.,  -50.,  -64., ..., -173., -162.,  -82.]), array(0)],
#  [array([ 98.,  88.,  76., ..., 244., 184.,  70.]), array(4)],
#  [array([-285., -308., -312., ...,  -67.,  -55., -107.]), array(4)],
#  [array([-21.,  -6.,   1., ..., -40., -15.,  23.]), array(0)],
#  [array([ -56.,  -55.,  -53., ..., -102.,  -73., -115.]), array(0)],
#  [array([31., 25., 17., ..., 23., 28., 65.]), array(0)],
#  [array([ 374., -205., -871., ...,  633.,  503.,  803.]), array(4)],
#  [array([-64., -62., -59., ..., -30., -41., -93.]), array(0)],
#  [array([  28.,   30.,    8., ..., -105.,  -95.,  -26.]), array(0)],
#  [array([466., 481., 440., ..., -72., -67., 523.]), array(4)],
#  [array([ 530.,  523.,  424., ...,  327.,  285., -925.]), array(4)],
#  [array([746., 692., 562., ..., 565., 677.,  11.]), array(4)],
#  [array([  68., -106., -149., ...,  343.,  247., -468.]), array(4)],
#  [array([-127., -164., -184., ...,  110.,   89.,  716.]), array(4)],
#  [array([-24., -29., -17., ...,  -7.,  -7.,  43.]), array(4)],
#  [array([ -8., -19., -32., ...,  27.,  41., -21.]), array(0)],
#  [array([-25.,   7.,  37., ..., -83., -69., -75.]), array(0)],
#  [array([-174., -392., -470., ...,  187.,  157., -260.]), array(4)],
#  [array([ -21.,  -17.,  -16., ..., -230., -207.,  -32.]), array(4)],
#  [array([ -2.,  20.,  42., ..., -18.,  -6., -37.]), array(0)],
#  [array([ -45., -105., -106., ...,   22.,    5.,   96.]), array(0)],
#  [array([ 401.,  577.,  667., ...,  -94.,  -77., -202.]), array(4)],
#  [array([  6., -14., -33., ...,  22.,  26., -88.]), array(0)],
#  [array([-19., -39., -41., ...,  60.,  46.,  46.]), array(0)],
#  [array([  -1.,  -11.,  -11., ...,  -31.,  -31., -111.]), array(0)],
#  [array([ 34.,  34.,  31., ...,  -7., -20.,  91.]), array(0)],
#  [array([ 457.,  420.,  344., ..., -226., -206., 1002.]), array(4)],
#  [array([-12.,   6.,  13., ..., -46., -30., -46.]), array(0)],
#  [array([46., 42., 29., ..., 36., 60., 44.]), array(0)],
#  [array([-58., -59., -60., ..., -43., -59.,  23.]), array(0)],
#  [array([ 61.,  42.,  23., ..., 318., 261., 177.]), array(4)],
#  [array([ -2.,  -8., -27., ...,  21.,  17., -16.]), array(0)],
#  [array([ 18.,  34.,  45., ..., -57., -53.,  83.]), array(0)],
#  [array([-49., -59., -56., ...,   8.,  -1., -44.]), array(0)],
#  [array([-149., -145., -135., ...,  -27.,  -27.,  228.]), array(4)],
#  [array([258., 309., 308., ...,  66.,  73., 206.]), array(4)],
#  [array([ 224.,  199.,  149., ...,  -56.,  -56., -101.]), array(4)],
#  [array([  45.,   51.,   62., ...,   -5.,    9., -282.]), array(4)],
#  [array([111., 112., 125., ..., 211., 181., -51.]), array(4)],
#  [array([-62., -55., -44., ..., -20., -22.,  35.]), array(0)],
#  [array([  59.,   37.,   25., ...,  366.,  199., -224.]), array(4)],
#  [array([-445., -645., -652., ...,  264.,  219., -346.]), array(4)],
#  [array([  13.,   21.,   39., ..., -107., -109.,  -25.]), array(0)],
#  [array([  84.,   75.,   21., ..., -209., -165., -212.]), array(4)],
#  [array([ 184., -160., -569., ...,  668.,  530.,  314.]), array(4)],
#  [array([264., 372., 410., ...,  -5.,  27., 464.]), array(4)],
#  [array([-224., -334., -411., ...,  380.,  294.,   32.]), array(4)],
#  [array([-81., -79., -76., ..., -27., -39., -70.]), array(0)],
#  [array([-265., -440., -627., ...,  -55.,  -74.,   -4.]), array(4)],
#  [array([-55., -32.,   1., ..., -73., -65., -39.]), array(0)],
#  [array([ -18.,  -55., -126., ..., -200., -127., -226.]), array(4)],
#  [array([475., 501., 477., ..., 103., 136.,  55.]), array(4)],
#  [array([  23.,  144.,  228., ..., -155.,    6., -221.]), array(4)],
#  [array([-166., -204., -209., ...,  368.,  313.,   51.]), array(4)],
#  [array([-41., -38., -31., ...,   1., -13.,  -1.]), array(0)],
#  [array([ -782., -1221., -1406., ...,    96.,  -299.,  -279.]), array(4)],
#  [array([19., 14., 23., ..., 62., 54., 40.]), array(0)],
#  [array([-20., -14., -12., ..., -66., -53.,   5.]), array(0)],
#  [array([-42., -49., -37., ..., -16., -19., -40.]), array(0)],
#  [array([  20.,   27.,   -5., ..., -111.,  -71.,   -9.]), array(0)],
#  [array([ 40.,  48.,  35., ..., -34., -27., -42.]), array(0)],
#  [array([-20., -43., -47., ...,  18.,   8., -63.]), array(0)],
#  [array([122., 117., 116., ..., -23.,  55.,  51.]), array(4)],
#  [array([ -26.,    1.,   29., ..., -207., -210., -107.]), array(4)],
#  [array([ 39.,  41.,  43., ..., -29., -16.,   1.]), array(0)],
#  [array([ 176.,  186.,  189., ...,  101.,   99., -554.]), array(4)],
#  [array([  27.,   55.,   75., ..., -476., -307.,  -21.]), array(4)],
#  [array([-64., -72., -52., ..., -36., -58.,  20.]), array(0)],
#  [array([-53., -46., -47., ..., -74., -80., -54.]), array(0)],
#  [array([ 231.,  214.,  187., ...,  243.,  198., -231.]), array(4)],
#  [array([ 69.,  68.,  58., ..., -83., -75.,  58.]), array(0)],
#  [array([ 43.,  48.,  44., ..., -47., -21.,  27.]), array(0)],
#  [array([81., 68., 35., ..., 15., 10., 17.]), array(0)],
#  [array([-377., -379., -396., ...,  -89., -132., -279.]), array(4)],
#  [array([286., 251., 214., ..., 334., 188., 315.]), array(4)],
#  [array([ 30.,  19.,  -3., ..., -11., -13.,  -6.]), array(0)],
#  [array([  39.,  152.,  257., ...,  -94.,  -97., -108.]), array(4)],
#  [array([  8.,  17.,  29., ..., -40., -36.,   7.]), array(0)],
#  [array([ 14.,  25.,  31., ..., -26., -28.,  21.]), array(0)],
#  [array([ 12.,  22.,  35., ..., -11.,   8.,  77.]), array(0)],
#  [array([ -3.,  -3., -12., ...,  30.,  19., -64.]), array(0)],
#  [array([ -7.,   4.,  21., ..., -94., -95.,  59.]), array(0)],
#  [array([ -36.,  -71., -120., ...,    3.,  -13.,   30.]), array(0)],
#  [array([-20.,  -3.,   2., ..., -28., -10.,   3.]), array(0)],
#  [array([-13., -27., -39., ..., -30., -34., -85.]), array(0)],
#  [array([ 13.,  30.,  42., ..., -36., -22., -39.]), array(0)],
#  [array([ -22.,  -63.,  -90., ...,   74.,   60., -106.]), array(4)],
#  [array([ -73.,  -66.,  -59., ..., -113., -109.,  -93.]), array(0)],
#  [array([-155., -283., -456., ...,  -27.,  -85., -449.]), array(4)],
#  [array([  555.,   611.,   658., ...,   347.,   369., -1468.]), array(4)],
#  [array([ -4.,   4.,  10., ..., -40., -45., -58.]), array(0)],
#  [array([-635., -573., -525., ..., -370., -415., -593.]), array(4)],
#  [array([ 96.,  43.,  71., ...,  51.,  90., -28.]), array(0)],
#  [array([80., 86., 91., ..., 54., 78., 89.]), array(4)],
#  [array([-133., -181., -166., ...,   95.,   19.,  385.]), array(4)],
#  [array([-46., -44., -47., ...,  43.,  56.,  14.]), array(0)]]

# %% [markdown]
# # Préparation des données

# %%
X_train
# Out:
# array([array([ 196.3510768 ,  179.23483508,  181.93072161,  163.83721981,
#                184.25158489,  184.51687767,  189.85223306,   15.32473   ,
#                108.13538151,  -18.90867574,   53.11403373,  159.43148789,
#                 -8.58091045,  -44.84426535,  -37.52076054,  159.28428833,
#                 63.40775591, -130.60286251,  184.1691861 ,   55.72093691,
#                  8.07636695,  -85.65322196, -133.53342863,  -49.01608259,
#                 14.92596355,  100.50327779,  181.50106022,  233.79205979,
#               -150.47543681,   54.86098676,   74.15157072,  110.46631038,
#                -62.0675572 ,  -49.37184974,  101.16196875,  143.97457086,
#                 37.43132415,   78.18644454,  -34.85468135,   97.8750972 ,
#                 -7.57223186,   72.01039279,  -47.43180063,  -93.97510387,
#               -119.97612052, -447.96989598, -220.10281788,  -70.67871186,
#                 53.91878649,  110.43130421, -163.70354113,  -59.16807819,
#                -43.02290973,  -18.10596826,  -25.56050081,  117.75324185,
#                163.16474692,  214.11661723,  304.7313196 ,  106.34402409,
#                 51.80393293,   59.709004  ,  204.29053101,  199.78242981,
#                107.45391824,  157.95971716,  162.63003282, -122.2291683 ,
#                195.09292193,  148.80573062,  134.39323124,   33.73008076,
#                -19.14897074, -153.56808074,   14.20983111,   15.3564633 ,
#                131.49469551,  156.45366431,  -77.94149781,   35.31901686,
#               -139.22229694,  -21.68134286,  -68.24913168,   26.44214057,
#                259.84499739,  -10.48069021,   44.47203779,   57.36726961,
#                -20.63714247,  100.32765052,  184.26907724,   43.43375509,
#                109.9641466 ,  138.27664932,   94.7795807 ,  -84.61914646,
#                 44.32422974,   84.21321743,  -93.40416922,  -38.92826169,
#                 64.64982235,   21.33312101,   50.75767919, -244.29294562,
#                 20.88143023,  -74.94523934,  -45.78312412, -122.96517695,
#                 -4.25503632,  140.38229727,  -63.85816998, -131.07945943,
#                  8.03151129,  -59.1948102 , -237.65415572, -128.98048447,
#               -115.47873135,   81.58981598,  112.2745668 ,  168.30558109,
#                147.66697657,  134.28529187,  185.6313839 ,   78.20048313,
#                146.3465838 ,  -44.54467904,  -68.26108075,   62.59286886,
#                 83.95168945,  -90.57681591,  124.26365076,   64.00159412,
#                203.17985783,   50.50866003,   98.31570446,    9.27047849,
#                -57.49356271,   -1.95979481, -110.78217604,  -36.23374546,
#                109.65737565,  230.9030288 ,  -10.607732  ,  279.87707655,
#                -28.05605233,    6.76175976,   37.34083182,  -11.60849807,
#                -76.47199832,  107.82856905, -121.73962528,   34.65084721,
#                 65.54086966,   24.08330646,   24.85537133,  -15.71326373,
#               -208.73051499,  -15.37442911,  -67.58472931,  -66.23034276,
#               -7.23352011e+01,  3.36653917e+01, -7.42218108e+01,  3.64974452e+01,
#               -2.56983548e+01,  3.44997318e+01, -5.27894870e+01,  1.07809844e+02,
#               -7.98670812e+01,  6.50198618e+01, -8.92786404e+01,  6.76315104e+01,
#               -1.11656668e+02,  7.79750620e+01,  2.36973167e+01, -3.90264762e+00,
#                1.01812340e+02,  6.74558606e+00,  1.39783043e+00,  2.82627814e+00,
#                3.65260276e+01, -4.47062618e+01,  4.30558681e+01, -5.18346387e+01,
#                1.29326149e+02, -9.23741733e+01,  4.41346760e+01, -5.77064758e+01,
#               -3.79410144e+01,  7.15436553e+00, -3.78234333e+01,  2.34299129e+01,
#               -7.34528803e+01,  3.45987222e+01, -5.00806577e+01,  1.00424545e+01,
#               -8.82650787e+01,  5.12594690e+01,  3.75623164e+01,  2.27030323e+01,
#               -1.29699640e+00])                                                  ],
#       dtype=object)

# %%
import numpy as np
from sklearn.utils import shuffle

data=wavelet_symlet_pso (data)
data = shuffle(data)

nb_train = round(len(data) * 0.8)
data_train = data[0:nb_train]
data_test = data[nb_train:]

X_train = np.array([d[0] for d in data_train])
Y_train = np.array([d[1] for d in data_train])

X_test = np.array([d[0] for d in data_test])
Y_test = np.array([d[1] for d in data_test])

X_train.shape
    
X_train = X_train.reshape(4097, 1)
Y_train = Y_train.reshape(Y_train.shape[0], 1)

X_test = X_test.reshape(X_test.shape[0], 4097, 1)
Y_test = Y_test.reshape(Y_test.shape[0], 1)
# Out:
# /usr/local/lib/python3.8/dist-packages/pywt/_multilevel.py:90: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   data = np.asarray(data)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-2e6725e5575f> in <module>
#       2 from sklearn.utils import shuffle
#       3
# ----> 4 data=wavelet_symlet_pso (data)
#       5 data = shuffle(data)
#       6
#
# <ipython-input-38-15cb6a7b4bc2> in wavelet_symlet_pso(data)
#       1 def wavelet_symlet_pso (data):
# ----> 2   data=pywt.wavedec(data, 'sym8',mode='sym', level=4)
#       3   return data
#
# /usr/local/lib/python3.8/dist-packages/pywt/_multilevel.py in wavedec(data, wavelet, mode, level, axis)
#      88
#      89     """
# ---> 90     data = np.asarray(data)
#      91
#      92     wavelet = _as_wavelet(wavelet)
#
# ValueError: could not broadcast input array from shape (200,270) into shape (200,)

# %% [markdown]
# # Construction du modèle LSTM (RNN)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import LSTM

#num_steps = 30
batch_size = 4
nb_epoch = 100
hidden_size = 64
use_dropout=True

model = Sequential()
model.add(LSTM(hidden_size, input_shape=(4097,1)))
#model.add(LSTM(64, return_sequences=False))

if use_dropout:
  model.add(Dropout(0.35))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['mae', 'acc'])

print(model.summary())

history = model.fit(X_train, Y_train, validation_split=0.2, batch_size=batch_size, nb_epoch=nb_epoch)
score = model.evaluate(X_test, Y_test, batch_size=batch_size)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 64)                16896
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
#  activation_1 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________
# None
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c1a100fdf96f> in <module>
#      23 print(model.summary())
#      24
# ---> 25 history = model.fit(X_train, Y_train, validation_split=0.2, batch_size=batch_size, nb_epoch=nb_epoch)
#      26 score = model.evaluate(X_test, Y_test, batch_size=batch_size)
#
# NameError: name 'X_train' is not defined
