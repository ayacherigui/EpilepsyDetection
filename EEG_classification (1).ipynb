# %% [markdown]
# # Installation de nouvelles bibliothèques nécessaires

# %%
# !pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Importation et labélisation des données

# %%
import os
from tqdm import tqdm
import glob
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

DATA_DIR_A = '/content/drive/MyDrive/A/'
DATA_DIR_B = '/content/drive/MyDrive/B/'
DATA_DIR_C = '/content/drive/MyDrive/C/'
DATA_DIR_D = '/content/drive/MyDrive/D/'
DATA_DIR_E = '/content/drive/MyDrive/E/'
  
LABEL_C1 = 0
#LABEL_C2 = 1
#LABEL_C3 = 2
#LABEL_C4 = 3
LABEL_C5 = 4
def load_data():
    data = []
    nbFiles = 0
    for fname in tqdm(os.listdir(DATA_DIR_A)):
        img = np.loadtxt(DATA_DIR_A + fname)
        data.append([img, np.array(LABEL_C1)])
        nbFiles+=1
    
    #for fname in tqdm(os.listdir(DATA_DIR_B)):
    #    img = np.loadtxt(DATA_DIR_B + fname)
   #     data.append([img, np.array(LABEL_C2)])
  #      nbFiles+=1    
    
    #for fname in tqdm(os.listdir(DATA_DIR_C)):
   #     img = np.loadtxt(DATA_DIR_C + fname)
  #    data.append([np.array(img), np.array(LABEL_C3)])
   #     nbFiles+=1

    #for fname in tqdm(os.listdir(DATA_DIR_D)):
    #    img = np.loadtxt(DATA_DIR_D + fname)
    #    data.append([np.array(img), np.array(LABEL_C4)])
    #    nbFiles+=1

    for fname in tqdm(os.listdir(DATA_DIR_E)):
        img = np.loadtxt(DATA_DIR_E + fname)
        data.append([img, np.array(LABEL_C5)])
        nbFiles+=1
        
    return data


data = load_data()
print("\n",len(data), "Files of data loaded")
# Out:
# ...
# 100%|██████████| 100/100 [00:02<00:00, 34.95it/s]
#  200 Files of data loaded

# %%
data
# Out:
# [[array([ 12.,  22.,  35., ..., -11.,   8.,  77.]), array(0)],
#  [array([ -56.,  -50.,  -64., ..., -173., -162.,  -82.]), array(0)],
#  [array([-37., -22., -17., ...,   3.,   4.,  82.]), array(0)],
#  [array([-31., -43., -39., ...,  -6.,  10.,  33.]), array(0)],
#  [array([ 14.,  26.,  32., ..., -32.,  -6., -17.]), array(0)],
#  [array([-87., -89., -73., ...,  18.,   7.,   7.]), array(0)],
#  [array([ -2.,  20.,  42., ..., -18.,  -6., -37.]), array(0)],
#  [array([-31., -16.,  10., ...,   1.,   1.,   0.]), array(0)],
#  [array([  8.,  17.,  29., ..., -40., -36.,   7.]), array(0)],
#  [array([-41., -38., -31., ...,   1., -13.,  -1.]), array(0)],
#  [array([ 14.,  25.,  31., ..., -26., -28.,  21.]), array(0)],
#  [array([-64., -72., -52., ..., -36., -58.,  20.]), array(0)],
#  [array([ 10.,  -6., -14., ...,  15.,   6., -46.]), array(0)],
#  [array([31., 25., 17., ..., 23., 28., 65.]), array(0)],
#  [array([ 30.,  19.,  -3., ..., -11., -13.,  -6.]), array(0)],
# ...

# %%
A_data=[]
for element in data:
  if (element[1]==np.array(0)):
    A_data.append(list(element[0]))
E_data=[]
for element in data:
  if (element[1]==np.array(4)):
    E_data.append(list(element[0]))
A_data
E_data
# Out:
# [[100.0,
#   124.0,
#   153.0,
#   185.0,
#   210.0,
#   220.0,
#   216.0,
#   222.0,
#   240.0,
#   265.0,
#   298.0,
#   330.0,
#   362.0,
#   381.0,
#   391.0,
#   390.0,
#   390.0,
#   392.0,
#   395.0,
#   397.0,
#   397.0,
#   393.0,
#   380.0,
#   356.0,
#   334.0,
#   322.0,
#   320.0,
#   322.0,
#   338.0,
#   332.0,
#   317.0,
#   263.0,
#   195.0,
#   142.0,
#   108.0,
#   97.0,
#   80.0,
#   80.0,
#   85.0,
#   39.0,
#   -139.0,
#   -816.0,
#   -1202.0,
#   -1374.0,
#   -1074.0,
#   -557.0,
#   -193.0,
#   51.0,
#   51.0,
#   272.0,
#   395.0,
#   407.0,
#   336.0,
#   209.0,
#   54.0,
#   -13.0,
#   -7.0,
#   48.0,
#   118.0,
#   233.0,
#   404.0,
#   578.0,
#   649.0,
#   627.0,
#   599.0,
#   577.0,
#   555.0,
#   483.0,
#   369.0,
#   224.0,
#   2.0,
#   -309.0,
#   -618.0,
#   -809.0,
#   -775.0,
#   -470.0,
#   -59.0,
#   343.0,
#   570.0,
#   600.0,
#   397.0,
#   58.0,
#   -456.0,
#   -718.0,
#   -773.0,
#   -507.0,
#   -77.0,
#   196.0,
#   394.0,
#   528.0,
# ...

# %% [markdown]
# # Visualisation d'un échantillon de données

# %%
import random
mpl.rcParams['figure.figsize'] = (20,10)

fig = plt.figure()

samples_c1 = np.empty((0, 4097), int)
while len(samples_c1) < 4:
    curID = random.randint(0, len(data))
    if data[curID][1] == LABEL_C1:
        samples_c1 = np.vstack((samples_c1, data[curID][0]))
        
samples_c2 = np.empty((0, 4097), int)
while len(samples_c2) < 4:
    curID = random.randint(0, len(data))
    if data[curID][1] == LABEL_C5:
        samples_c2 = np.vstack((samples_c2, data[curID][0]))
        
for i in range(0, 4):
    plt.subplot(421 + i * 2)
    plt.plot(samples_c1[i])
    plt.subplot(421 + i * 2 + 1)
    plt.plot(samples_c2[i])

ax = plt.subplot(421)
ax.set_title("CLASS 1")
ax = plt.subplot(422)
ax.set_title("CLASS 5")

fig.suptitle("A vs E", fontsize=20)
plt.show()
# Out:
# <ipython-input-6-3d5b7a4df8ed>:24: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(421)
# <ipython-input-6-3d5b7a4df8ed>:26: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot(422)

# %% [markdown]
# #Pré-traitement des données

# %%
# !pip install PyWavelets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pywt

# %%
def wavelet_haar_pso (data):
  data=pywt.wavedec(data, 'haar',mode='sym', level=4)
  return data

# %%
def wavelet_daubechie_pso (data):
  data=pywt.wavedec(data, 'db4',mode='sym', level=4)
  return data

# %%
def wavelet_symlet_pso (data):
  data=pywt.wavedec(data, 'sym8',mode='sym', level=4)
  return data

# %%
pywt.wavelist()
# Out:
# ['bior1.1',
#  'bior1.3',
#  'bior1.5',
#  'bior2.2',
#  'bior2.4',
#  'bior2.6',
#  'bior2.8',
#  'bior3.1',
#  'bior3.3',
#  'bior3.5',
#  'bior3.7',
#  'bior3.9',
#  'bior4.4',
#  'bior5.5',
#  'bior6.8',
#  'cgau1',
#  'cgau2',
#  'cgau3',
#  'cgau4',
#  'cgau5',
#  'cgau6',
#  'cgau7',
#  'cgau8',
#  'cmor',
#  'coif1',
#  'coif2',
#  'coif3',
#  'coif4',
#  'coif5',
#  'coif6',
#  'coif7',
#  'coif8',
#  'coif9',
#  'coif10',
#  'coif11',
#  'coif12',
#  'coif13',
#  'coif14',
#  'coif15',
#  'coif16',
#  'coif17',
#  'db1',
#  'db2',
#  'db3',
#  'db4',
#  'db5',
#  'db6',
#  'db7',
#  'db8',
#  'db9',
#  'db10',
#  'db11',
#  'db12',
#  'db13',
#  'db14',
#  'db15',
#  'db16',
#  'db17',
#  'db18',
#  'db19',
#  'db20',
#  'db21',
#  'db22',
#  'db23',
#  'db24',
#  'db25',
#  'db26',
#  'db27',
#  'db28',
#  'db29',
#  'db30',
#  'db31',
#  'db32',
#  'db33',
#  'db34',
#  'db35',
#  'db36',
#  'db37',
#  'db38',
#  'dmey',
#  'fbsp',
#  'gaus1',
#  'gaus2',
#  'gaus3',
# ...

# %%
A_pp=[]
for element in A_data:
  A_pp.append(list(wavelet_haar_pso(element)))
E_pp=[]
for element in A_data:
  E_pp.append(list(wavelet_haar_pso(element)))

# %%
"""A_pp=[]
for element in A_data:
  A_pp.append(list(wavelet_daubechie_pso(element)))
E_pp=[]
for element in A_data:
  E_pp.append(list(wavelet_daubechie_pso(element)))"""
# Out:
# 'A_pp=[]\nfor element in A_data:\n  A_pp.append(list(wavelet_daubechie_pso(element)))\nE_pp=[]\nfor element in A_data:\n  E_pp.append(list(wavelet_daubechie_pso(element)))'

# %%
"""A_pp=[]
for element in A_data:
  A_pp.append(list(wavelet_symlet_pso(element)))
E_pp=[]
for element in A_data:
  E_pp.append(list(wavelet_symlet_pso(element)))"""
# Out:
# 'A_pp=[]\nfor element in A_data:\n  A_pp.append(list(wavelet_symlet_pso(element)))\nE_pp=[]\nfor element in A_data:\n  E_pp.append(list(wavelet_symlet_pso(element)))'

# %%
final_data=[]
for i in range(100):
    final_data.append([A_pp[i],np.array(0)])
for j in range(100):
    final_data.append([E_pp[i],np.array(4)])

# %%
data
# Out:
# [[array([ 12.,  22.,  35., ..., -11.,   8.,  77.]), array(0)],
#  [array([ -56.,  -50.,  -64., ..., -173., -162.,  -82.]), array(0)],
#  [array([-37., -22., -17., ...,   3.,   4.,  82.]), array(0)],
#  [array([-31., -43., -39., ...,  -6.,  10.,  33.]), array(0)],
#  [array([ 14.,  26.,  32., ..., -32.,  -6., -17.]), array(0)],
#  [array([-87., -89., -73., ...,  18.,   7.,   7.]), array(0)],
#  [array([ -2.,  20.,  42., ..., -18.,  -6., -37.]), array(0)],
#  [array([-31., -16.,  10., ...,   1.,   1.,   0.]), array(0)],
#  [array([  8.,  17.,  29., ..., -40., -36.,   7.]), array(0)],
#  [array([-41., -38., -31., ...,   1., -13.,  -1.]), array(0)],
#  [array([ 14.,  25.,  31., ..., -26., -28.,  21.]), array(0)],
#  [array([-64., -72., -52., ..., -36., -58.,  20.]), array(0)],
#  [array([ 10.,  -6., -14., ...,  15.,   6., -46.]), array(0)],
#  [array([31., 25., 17., ..., 23., 28., 65.]), array(0)],
#  [array([ 30.,  19.,  -3., ..., -11., -13.,  -6.]), array(0)],
# ...

# %%
listdata=[]
for i in range (100):
  listdata.append([np.concatenate((final_data[i][0][0],final_data[i][0][1][0:256],final_data[i][0][2][0:512],final_data[i][0][3][0:1024],final_data[i][0][4][0:2048])),np.array(0)])
for i in range(100):
  listdata.append([np.concatenate((final_data[i][0][0],final_data[i][0][1][0:256],final_data[i][0][2][0:512],final_data[i][0][3][0:1024],final_data[i][0][4][0:2048])),np.array(4)])

# %% [markdown]
# # Préparation des données

# %%
import numpy as np
from sklearn.utils import shuffle

Data = shuffle(listdata)

nb_train = round(len(Data) * 0.8)
data_train = Data[0:nb_train]
data_test = Data[nb_train:]

X_train = np.array([d[0] for d in data_train],dtype=object)
Y_train = np.array([d[1] for d in data_train])

X_test = np.array([d[0] for d in data_test],dtype=object)
Y_test = np.array([d[1] for d in data_test])

X_train.shape
# Out:
# (160, 4097)

# %%
X_train = X_train.reshape(X_train.shape[0], 4097,1)
Y_train = Y_train.reshape(Y_train.shape[0],1)

X_test = X_test.reshape(X_test.shape[0], 4097,1)
Y_test = Y_test.reshape(Y_test.shape[0],1)

# %% [markdown]
# # Construction du modèle LSTM (RNN)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding
from keras.layers import LSTM

#num_steps = 30
batch_size = 4
nb_epoch = 100
hidden_size = 64
use_dropout=True

model = Sequential()
model.add(LSTM(hidden_size, input_shape=(4097,1)))
#model.add(LSTM(64, return_sequences=False))

if use_dropout:
  model.add(Dropout(0.35))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['mae', 'acc'])

print(model.summary())


history = model.fit(X_train.astype(np.float32), Y_train.astype(np.float32), validation_split=0.2, batch_size=batch_size, epochs=100)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_3 (LSTM)               (None, 64)                16896
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
#  activation_3 (Activation)   (None, 1)                 0
#
# ...
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 32/32 [==============================] - 35s 1s/step - loss: -0.2888 - mae: 1.9270 - acc: 0.0391 - val_loss: -2.9196 - val_mae: 2.1272 - val_acc: 0.0000e+00
# Epoch 2/100
# 32/32 [==============================] - 32s 1s/step - loss: -4.5281 - mae: 1.9334 - acc: 0.0000e+00 - val_loss: -9.5272 - val_mae: 2.1252 - val_acc: 0.0000e+00
# Epoch 3/100
# ...

# %%
score = model.evaluate(X_test.astype(np.float32), Y_test.astype(np.float32), batch_size=batch_size)
# Out:
# 10/10 [==============================] - 2s 238ms/step - loss: -156.3867 - mae: 2.1000 - acc: 0.0000e+00
